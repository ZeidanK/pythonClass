# %% [markdown]
# #INTRODUCTION TO PYTHON
# # PANDAS SERIES
#
# By: Marcelo Feighelstein

# %% [markdown]
# #Problem 1
# Load the file **"/content/tweeter username and followers.csv"** from Moodle and read the content in a Pandas series named "username_and followers". Print how many usernames and how many followers are in total in the "username_and followers" series.
#
# Expected Results
# username_and_followers 719
# user_followers_count 8485154

# %% [markdown]
# #Problem 2
# Build a tweet_users_dict dictionary with two lists with keys: Username and Followers. Create two lists of Usernames and Followers from the list you read in previous question.
# Note: you must skip the first read element with description of columns
#
# Example
#
# tweet_users_dict = {'Followers': ['1860',
#   '1067661',
#   '1185',
#   '32',
#   '5393',
#   '2363',......],
#
#   'Username': ['elsollatinonews',
#   'MediasetTgcom24',
#   'snarke',
#   'trumpytweeter',
#   'Ranaabtar',
#   'FarrisFlagg',....],
# }
#
# The result is a dictonary with two keys "Followers" and "Username". The value of each key is the list of number of followers and list of usernames on list of Problem 1

# %% [markdown]
# # Problem 3
#  Build  list with lists having the index number, the Username and the number of followers of all Followers including the words 'love' or 'hate' (Note: those words can be written with any combination of lowercases and uppercases)
#
# Expected Result:
#
# 404 LoveIrreverence 1486
#
# 481 LovelyRita1022 1526
#
# 567 hatepoliticstoo 12
#
#
# The reason for such output is because the usernames "LoveIrreverance" and "LoveltyRita1022" on this list of Problem 1 contains the word "love" and the username "hatepolitcstoo" contains the word "hate"

# %% [markdown]
# # Problem 4
# Write the content of the list of elemtns of previous question into a file name "output_file.txt" with every element in a different line and each part of the element separated by commas (,)
#
#
# When you open the csv file in your computer with Excel, you should see
# the following lines:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
