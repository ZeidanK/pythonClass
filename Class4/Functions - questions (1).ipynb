# %% [markdown]
# # FUNCTIONS
#
# By: Marcelo Feighelstein

# %% [markdown]
# #Problem 1
# Write a function split_string that receive two paramters: string and position. The function returns a list of two elements: all characters on input string until position (including) and the rest of the characters in the second element. If the position is out of the string the function returns ['Error','Error']. Write a lines calling the function (with and without errors)

# %% [markdown]
# #Problem 2
# Write a Python function that checks whether a passed string is palindrome or not.  Note: A palindrome is a word, phrase, or sequence that reads the same backward as forward, e.g., madam or nurses run.
