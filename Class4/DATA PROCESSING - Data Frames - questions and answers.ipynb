# %% [markdown]
# #INTRODUCTION TO PYTHON - QUESTIONS AND ANSWERS
# #LESSON 8
#
# By: Marcelo Feighelstein

# %%
import pandas as pd
titanic_pd = pd.read_csv('/content/titanic passengers - partial.csv')

# %%
titanic_pd.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(type(titanic_pd [ 'Survived' ]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(titanic_pd [ 'Sex' ]))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### A dataframe is a table compound of columns.
# ### Every columns is a Pandas Series

# %% [markdown]
# # Problem 1
# How many men and women do we see in the list of passengers?

# %%
print(titanic_pd [ 'Sex' ].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# # Problem 2
# Print the list of embarking ports of passenger.

# %%
print(titanic_pd [ 'Embarked' ].unique())
# Out:
# ['S' 'C' 'Q' nan]

# %% [markdown]
# # Problem 3
# Print the statistics of age of passenger.

# %%
print(titanic_pd [ 'Age' ].describe())
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# # Problem 4
# Print the list of passenger who survived.

# %%
print(titanic_pd [ titanic_pd [ 'Survived' ] == 1 ])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Problem 5
# Print the number of passenger who survived.

# %%
print(titanic_pd [ titanic_pd [ 'Survived' ] == 1 ]['PassengerId'].count())
# Out:
# 342

# %% [markdown]
# # Problem 6
# Print the age of the older passenger

# %%
print(max(titanic_pd ['Age']))
# Out:
# 80.0

# %% [markdown]
# # Problem 7
# Print the average fare paid by males and females on the Titanic

# %%
print(titanic_pd.groupby('Sex')['Fare'].mean())
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
print(titanic_pd ['Age'].sort_values(ascending=False))
# Out:
# 630    80.0
# 851    74.0
# 493    71.0
# 96     71.0
# 116    70.5
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# # Problem 8
# Print the name of the oldest passenger on the Titanic

# %%
print(titanic_pd.sort_values(by=['Age'],ascending=False)['Name'].values[0])
# Out:
# Barkworth, Mr. Algernon Henry Wilson

# %%
print(titanic_pd.sort_values(by=['Age'],ascending=False))
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
print(titanic_pd.sort_values(by=['Age'],ascending=False)['Name'])
# Out:
# 630        Barkworth, Mr. Algernon Henry Wilson
# 851                         Svensson, Mr. Johan
# 493                     Artagaveytia, Mr. Ramon
# 96                    Goldschmidt, Mr. George B
# 116                        Connors, Mr. Patrick
#                          ...
# 859                            Razi, Mr. Raihed
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 891, dtype: object

# %%
print(titanic_pd.sort_values(by=['Age'],ascending=False)['Name'].values)
# Out:
# ['Barkworth, Mr. Algernon Henry Wilson' 'Svensson, Mr. Johan'
#  'Artagaveytia, Mr. Ramon' 'Goldschmidt, Mr. George B'
#  'Connors, Mr. Patrick' 'Mitchell, Mr. Henry Michael'
#  'Crosby, Capt. Edward Gifford' 'Wheadon, Mr. Edward H'
#  'Ostby, Mr. Engelhart Cornelius' 'Duane, Mr. Frank'
#  'Millet, Mr. Francis Davis' 'Fortune, Mr. Mark'
#  'Nicholson, Mr. Arthur Ernest' 'Andrews, Miss. Kornelia Theodosia'
#  'Turkula, Mrs. (Hedwig)' 'Harris, Mr. George' 'Stead, Mr. William Thomas'
#  'Stone, Mrs. George Nelson (Martha Evelyn)' 'Wright, Mr. George'
#  'Sutton, Mr. Frederick' 'Nysveen, Mr. Johan Hansen'
#  'Van der hoef, Mr. Wyckoff' 'Brown, Mr. Thomas William Solomon'
#  'Weir, Col. John' 'Frolicher-Stehli, Mr. Maxmillian'
#  'Warren, Mrs. Frank Manley (Anna Sophia Atkinson)' 'Coxon, Mr. Daniel'
#  'Sjostedt, Mr. Ernst Adolf'
#  'Graham, Mrs. William Thompson (Edith Junkins)'
#  'Bonnell, Miss. Elizabeth' 'Lurette, Miss. Elise'
# ...

# %%
print(titanic_pd.sort_values(by=['Age'],ascending=False)['Name'].values[-1])
# Out:
# Johnston, Miss. Catherine Helen "Carrie"

# %% [markdown]
# # Problem 9
# Print the name of the youngest passenger that survived on the Titanic

# %%
print(titanic_pd [titanic_pd [ 'Survived']==1 ].sort_values(by=['Age'],ascending=False)['Name'].values[-1])
# Out:
# Goldenberg, Mrs. Samuel L (Edwiga Grabowska)

# %%
print(titanic_pd [titanic_pd [ 'Name' ] =='Goldenberg, Mrs. Samuel L (Edwiga Grabowska)'] )
# Out:
#      PassengerId  Survived  Pclass  \
# 849          850         1       1
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1      0
#
#     Ticket     Fare Cabin Embarked
# 849  17453  89.1042   C92        C

# %%
agenotnull = titanic_pd [~titanic_pd [ 'Age'].isnull() ]
survived = agenotnull [agenotnull [ 'Survived']==1 ]
print(survived.sort_values(by=['Age'],ascending=False)['Name'].values[-1])
# Out:
# Thomas, Master. Assad Alexander

# %%
print(titanic_pd [titanic_pd [ 'Name' ] =='Thomas, Master. Assad Alexander'] )
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C
