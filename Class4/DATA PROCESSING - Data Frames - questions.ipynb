# %% [markdown]
# #INTRODUCTION TO PYTHON - QUESTIONS
# #DATA FRAMES
#
# By: Marcelo Feighelstein

# %%
import pandas as pd
titanic_pd = pd.read_csv('/content/titanic passengers - partial.csv')

# %%
titanic_pd.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(titanic_pd.columns)
# Out:
# 12

# %%
len(titanic_pd)
# Out:
# 891

# %%
titanic_pd.shape[1]
# Out:
# 12

# %%
titanic_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_pd.isnull().sum().sum()
# Out:
# 866

# %%
print(type(titanic_pd [ 'Survived' ]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(titanic_pd [ 'Sex' ])
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %% [markdown]
# ### A dataframe is a table compound of columns.
# ### Every columns is a Pandas Series

# %% [markdown]
# # Problem 1
# How many men and women do we see in the list of passengers?

# %%
print(titanic_pd [ 'Sex' ].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
print(titanic_pd [ 'Sex' ].value_counts().loc['male'])
# Out:
# 577

# %%
print(titanic_pd [ 'Sex' ].value_counts().loc['female'])
# Out:
# 314

# %% [markdown]
# # Problem 2
# Print the list of embarking ports of passenger.

# %%
print(titanic_pd [ 'Embarked' ].value_counts(dropna=False))
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
print(list(titanic_pd['Embarked']))
# Out:
# ['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'C', 'S', 'S', 'Q', 'S', 'S', 'S', 'C', 'S', 'Q', 'S', 'C', 'C', 'Q', 'S', 'C', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'C', 'C', 'Q', 'S', 'Q', 'Q', 'C', 'S', 'S', 'S', 'C', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'C', nan, 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'C', 'S', 'S', 'C', 'S', 'Q', 'S', 'C', 'S', 'S', 'S', 'C', 'S', 'S', 'C', 'Q', 'S', 'C', 'S', 'C', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S', 'Q', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'C', 'C', 'Q', 'S', 'Q', 'S
# ...

# %%
print(list(titanic_pd [ 'Embarked' ].value_counts(dropna=True).index))
# Out:
# ['S', 'C', 'Q']

# %%
print(titanic_pd [ 'Embarked' ].unique()[:-1])
# Out:
# ['S' 'C' 'Q']

# %% [markdown]
# # Problem 3
# Print the statistics of age of passenger.

# %%
print(titanic_pd [ 'Age'].describe())
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
print(titanic_pd [ 'Age'].argmax())
# Out:
# 630

# %% [markdown]
# # Problem 4
# Print the list of passenger who survived.

# %%
print(list(titanic_pd [ titanic_pd['Survived'] == 1]['Name']))
# Out:
# ['Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Heikkinen, Miss. Laina', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 'Nasser, Mrs. Nicholas (Adele Achem)', 'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth', 'Hewlett, Mrs. (Mary D Kingcome) ', 'Williams, Mr. Charles Eugene', 'Masselmani, Mrs. Fatima', 'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"', 'Sloper, Mr. William Thompson', 'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)', 'O\'Dwyer, Miss. Ellen "Nellie"', 'Spencer, Mrs. William Augustus (Marie Eugenie)', 'Glynn, Miss. Mary Agatha', 'Mamee, Mr. Hanna', 'Nicola-Yarred, Miss. Jamila', 'Laroche, Miss. Simonne Marie Anne Andree', 'Devaney, Miss. Margaret Delia', "O'Driscoll, Miss. Bridget", 'Harper, Mrs. Henry Sleeper (Myna Haxtun)', 'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)', 'Woolner, Mr. Hugh', 'Rugg, Miss. Emily', 'West, Miss. Constance Mirium', 'Icard, Miss. Amelie', 'Moub
# ...

# %% [markdown]
# # Problem 5
# Print the number of passenger who survived.

# %%
print(len(list(titanic_pd [ titanic_pd['Survived'] == 1]['Name'])))
# Out:
# 342

# %%
titanic_pd.groupby("Survived").count() #.loc[1]["PassengerId"]
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %% [markdown]
# # Problem 6
# Print the age of the older passenger

# %%
print(titanic_pd['Age'].max())
# Out:
# 80.0

# %% [markdown]
# # Problem 7
# Print the average fare paid by males and females on the Titanic

# %%
print(titanic_pd [  titanic_pd['Sex'] == 'male']['Fare'].mean())
# Out:
# 25.523893414211443

# %%
print(titanic_pd [  titanic_pd['Sex'] == 'female']['Fare'].mean())
# Out:
# 44.47981783439491

# %% [markdown]
# # Problem 8
# Print the name of the oldest passenger on the Titanic

# %%
index_of_oldest = titanic_pd['Age'].argmax()
print(index_of_oldest)
# Out:
# 630

# %%
print(titanic_pd.loc[index_of_oldest].Name)
# Out:
# Barkworth, Mr. Algernon Henry Wilson

# %%
print(titanic_pd.loc[titanic_pd['Age'].argmax()].Name)
# Out:
# Barkworth, Mr. Algernon Henry Wilson

# %% [markdown]
# # Problem 9
# Print the name of the youngest passenger that survived on the Titanic

# %%
age_of_min = titanic_pd [titanic_pd['Survived'] == 1]['Age'].min()

# %%
print(age_of_min)
# Out:
# 0.42

# %%
 list(titanic_pd [ titanic_pd [ 'Age'] == age_of_min ].Name)[0]
# Out:
# 'Thomas, Master. Assad Alexander'

# %%
titanic_pd [ titanic_pd [ 'Age'] == age_of_min ]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
 list(titanic_pd [ titanic_pd [ 'Age'] == age_of_min ].Name)

# %%
new_table = titanic_pd [titanic_pd['Survived'] == 1]

# %%
index_of_min = new_table['Age'].argmin()

# %%
print(index_of_min)
# Out:
# 310

# %%
new_table.loc[index_of_min]
# Out:
# PassengerId                               311
# Survived                                    1
# Pclass                                      1
# Name           Hays, Miss. Margaret Bechstein
# Sex                                    female
# Age                                      24.0
# SibSp                                       0
# Parch                                       0
# Ticket                                  11767
# Fare                                  83.1583
# Cabin                                     C54
# Embarked                                    C
# Name: 310, dtype: object
