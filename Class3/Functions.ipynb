# %% [markdown]
# * ## Functions

# %% [markdown]
# # Motivation
#
# Let's start coding and see what happens...
#
# Write code that receives as input three numbers A, B and C and calculates the factorial of A (A!) , the factorial of B (B!) and the factorial of C (C!).
#
# n! = 1 x 2 x 3 x .... x (n-1) x n

# %%
A = int(input("Enter number A:"))
B = int(input("Enter number B:"))
C = int(input("Enter number C:"))
# Out:
# Enter number A:9
# Enter number B:5
# Enter number C:-6

# %%
print(A,B,C)
# Out:
# 9 5 -6

# %%
A_fact = 1
if A < 0:
  print("Error")
elif A == 1:
    print(1)
else:
  for i in range(1,A+1):
    A_fact*=i
  print(A_fact)
# Out:
# 362880

# %%
B_fact = 1
if B < 0:
  print("Error")
elif B == 1:
    print(1)
else:
  for i in range(2,B+1):
    B_fact*=i
  print(B_fact)
# Out:
# 120

# %%
C_fact = 1
if C < 0:
  print("Error")
elif C == 1:
    print(1)
else:
  for i in range(2,C+1):
    C_fact*=i
  print(C_fact)
# Out:
# Error

# %% [markdown]
# #Functions
# * ## A function is a block of code which only runs when it is called
# * ## You can pass data, known as parameters, into a function
# * ## A function can return data as a result

# %% [markdown]
# ## Defining a function:

# %%
def my_function():
  print("This is a print: Hello from a function")#everything with the tab indent is part of the function

# %% [markdown]
# ## Calling a function

# %%
my_function()
my_function()
# Out:
# Hello from a function
# Pikado
# Hello from a function
# Pikado

# %% [markdown]
# ##Functions can return data

# %%
def funct_with_return():
  return 5

print(funct_with_return())
print(funct_with_return())
# Out:
# 5
# 5

# %%
x = funct_with_return()
print(x)
# Out:
# 5

# %% [markdown]
# ## Arguments
# * ### Information can be passed into functions as arguments
# * ### We add them inside the parentheses after function name

# %%
def func_with_arg(x, y, z):
  a = x+y-z
  return a

print(func_with_arg(1,2,3))
print(func_with_arg(4,5,6))
print(func_with_arg(3,2,1))
#print(func_with_arg("aaa", "bbb","ccc"))
# Out:
# 0
# 3
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       6 print(func_with_arg(4,5,6))
#       7 print(func_with_arg(3,2,1))
# ----> 8 print(func_with_arg("aaa", "bbb","ccc"))
#
# Cell In[3], line 2, in func_with_arg(x, y, z)
#       1 def func_with_arg(x, y, z):
# ----> 2   a = x+y-z
#       3   return a
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
print(func_with_arg(3.34,2,1.11))
# Out:
# 4.2299999999999995

# %% [markdown]
# ### Variables inside a function **do not** exist outside the function

# %%
def func_with_var(x, y):
  a = x+y
  return a**2

res = func_with_var(1,2)
print(res)
print(x)  # will raise error
print(a)  # will raise error
# Out:
# 9
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-84b5d1bce89e> in <cell line: 8>()
#       6 print(res)
#       7 print(x)  # will raise error
# ----> 8 print(a)  # will raise error
#
# NameError: name 'a' is not defined

# %% [markdown]
# ###Default value

# %%
def h(x, y=5):
  return x*y

print(h(2))
print(h(2, 4))
print(h(x=3, y=2))
print(h(y=3, x=2))
# Out:
# 10
# 8
# 6
# 6

# %% [markdown]
# # Function example:
# Write code that receives as input three numbers A, B and C and prints the factorial of A (A!) , the factorial of B (B!) and the factorial of C (C!).
#
# n! = 1 x 2 x 3 x .... x (n-1) x n

# %%
def fact(n):
    n_fact = 1
    if n < 0:
      print("Error")
    elif n == 1:
        print(1)
    else:
      for i in range(2,n+1):
        n_fact*=i
      print(n_fact)

# %%
fact(9)
# Out:
# 362880

# %%
fact(1)
# Out:
# 1

# %%
fact(-5)
# Out:
# Error

# %%
x = fact(9)
# Out:
# 362880

# %%
print(x)
# Out:
# None

# %% [markdown]
# # NOTE: FUNCTION FACT DOES NOT RETURN ANY VALUE!!

# %%
x = fact(5)
# Out:
# 120

# %%
print(x)
# Out:
# None

# %% [markdown]
# # Function example:
# Write code that receives as input three numbers A, B and C and returns the factorial of A (A!) , the factorial of B (B!) and the factorial of C (C!).
#
# n! = 1 x 2 x 3 x .... x (n-1) x n

# %%
def fact(n):
    n_fact = 1
    if n < 0:
      return "ERROR"
    elif n == 1:
        return 1
    else:
      for i in range(2,n+1):
        n_fact*=i
      return n_fact

# %%
print(fact(9))
# Out:
# 362880

# %%
x = fact(9)

# %%
print(x)
# Out:
# 362880

# %% [markdown]
# ## Function example:
# ### Write a function that recives a string of a sentence and returns a new string of the sentence reversed.
# ### **input**: one two three four
# ### **output**: four three two one

# %%
def reverse_sentece(sentence):
  split_sentence = sentence.split(" ")#split_sentence default is the same (" ") it will split on spaces
  print(split_sentence)
  reversed_lst = split_sentence[::-1]#switch the order of the split_sentence into reversed_lst
  print(reversed_lst)
  rev_sentence = " ".join(reversed_lst)#rejoin the reversed sentence to one string
  return rev_sentence

sentence = "one two three four"
print(reverse_sentece(sentence))
# Out:
# ['one', 'two', 'three', 'four']
# ['four', 'three', 'two', 'one']
# four three two one

# %% [markdown]
# ## Another example:
# ### Write a function that recives a string and prints a histogram of the letters appearance (the number of times each letter appears).
# ### **input**: "this is a string"
# ### **will print**:
# ###t    2
# ###h    1
# ###i    3
# ###s    3
# ###$\space$     3
# ###a    1
# ###r    1
# ###n    1
# ###g    1

# %%
d = {}
d [ 1 ] = 2
def new_fun(string):
    for letter in string:
        if letter in d:
            d[letter] += 1
        else:
            d[letter] = 1
    return d

# %%
print(d)
# Out:
# {1: 2}

# %%
def letters_hist(string):
  letters_dict = {}
  for letter in string:
    if letter in letters_dict.keys():
      letters_dict[letter] += 1
    else:
      letters_dict[letter] = 1
  for key in letters_dict.keys():
    print(key, "  ", letters_dict[key])

sentence = "this is a string"
letters_hist(sentence)
# Out:
# t    2
# h    1
# i    3
# s    3
#      3
# a    1
# r    1
# n    1
# g    1

# %% [markdown]
# # Another Example
# Write a function print_list that receives as parameter a list LIST, the starting position START and a step STEP and prints the elements of LIST starting at position START with increment STEP

# %%
def print_list(LIST, START = 1, STEP = 1):
  if START < 0 or START >= len(LIST):
    return "ERROR"
  for index in range(START-1,len(LIST),STEP):
    print(LIST[index])

# %%
print_list(["This","is",5,"an","888","example",987])
# Out:
# This
# is
# 5
# an
# 888
# example
# 987

# %%
print_list(["This","is",5,"an","888","example",987],2,2)
# Out:
# is
# an
# example
