# %% [markdown]
# # PYTHON CS - HW1 - Questions

# %% [markdown]
# # GENERAL REQUIREMENT:
#
# In all questions your implementation should handle wrong inputs or parameters (bad types, etc) (for example print "Bad Input of type...").

# %% [markdown]
# # Question 1
# Write code receiving from user a numerical parameter NUMBER and printing the sum of all digits on even positions (2,4,...).
# Digit number one is the least significant (i.e. in number 702 the digit in position number 1 is 2, in position number 2 is 0 and in position number 3 is 7)
# Write a code entering an integer number from the user and printing the result of the function COUNT_EVEN_POSITION_DIGITS (do that few times).
#
# Example:
#
# for NUMBER=1234 the function returns 4 (3 in position 2 and 1 in position 4).

# %%
# write your code here

# %% [markdown]
# # Question 2
# Write code receiving from user an integer parameter N, char SIGN and char INTER printing a SIGNED-based form as in the following example. Write code with few examples asking user to enter different N, SIGN and INTER.
#
# Examples:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# write your code here

# %% [markdown]
# # Question 3
# Write python code receiving from user a sentence in variable TEXT. The code returns two lists: (1) list of words included in TEXT that starts with an UPPERCASE letter and (2) previous list of words included in (1) but only their vowels letters (a,e,i,o,u). The function must check correctness of parameter.
#
# Example:
#
# FILTER_WORDS("This is an Example of a Text hAving a miXTURE of 12345 types MMMMM") will return ['This', 'Example', 'Text', 'MMMMM'], ['i', 'Eae', 'e', '']

# %%
# write your code here

# %% [markdown]
# #Question 4
# Given a table in the format displayed below contained in a list table_str.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
table_str = ["Length","Count",'Percent','CDF',
             "1","70","0.23%","0.23%",
             "2","704","2.26%","2.49%",
             "3","1055","3.39%","5.88%",
             "4","1386","4.46%","10.34%",
             "5","1269","4.08%","14.42%",
             "6","1140","3.67%","18.09%",
             "7","1090","3.51%","21.59%",
             "8","1189","3.82%","25.42%",
             "9","1268","4.08%","29.49%",
             "10","1086","3.49%","32.99%",
             "11","920","2.96%","35.95%",
             "12","931","2.99%","38.94%",
             "13","819","2.63%","41.57%",
             "14","1016","3.27%","44.84%",
             "15","918","2.95%","47.79%",
             "16","853","2.74%","50.54%",
             "17","721","2.32%","52.86%",
             "18","711","2.29%","55.14%",
             "19","727","2.34%","57.48%",
             "20","554","1.78%","59.26%"]

# %% [markdown]
# ##Question 4.1:
# Convert the list table_str into a list of lists named table_list as follows:
#
# (NOTE: a list of lists with 4 elements each)
# [['Length', 'Count', 'Percent', 'CDF'], ['1', '70', '0.23%', '0.23%'], ['2', '704', '2.26%', '2.49%'], ['3', '1055', '3.39%', '5.88%'], ['4', '1386', '4.46%', '10.34%'], ['5', '1269', '4.08%', '14.42%'], ['6', '1140', '3.67%', '18.09%'], ['7', '1090', '3.51%', '21.59%'], ['8', '1189', '3.82%', '25.42%'], ['9', '1268', '4.08%', '29.49%'], ['10', '1086', '3.49%', '32.99%'], ['11', '920', '2.96%', '35.95%'], ['12', '931', '2.99%', '38.94%'], ['13', '819', '2.63%', '41.57%'], ['14', '1016', '3.27%', '44.84%'], ['15', '918', '2.95%', '47.79%'], ['16', '853', '2.74%', '50.54%'], ['17', '721', '2.32%', '52.86%'], ['18', '711', '2.29%', '55.14%'], ['19', '727', '2.34%', '57.48%'], ['20', '554', '1.78%', '59.26%']]

# %%
# write your code here

# %% [markdown]
# ##Question 4.2:
# Build a new list named output_list converting every element of list table_str  according to the following rules:
# * Text fields remain as string
# * Integer fields are converted to int
# * Percentage fields are converted to float(after removing the '%' sign)
#
# Results show be as follows:
#
#
# [['Length', 'Count', 'Percent', 'CDF'], [1, 70, 0.0023, 0.0023], [2, 704, 0.0226, 0.024900000000000002], [3, 1055, 0.0339, 0.0588], [4, 1386, 0.0446, 0.10339999999999999], [5, 1269, 0.0408, 0.1442], [6, 1140, 0.036699999999999997, 0.1809], [7, 1090, 0.0351, 0.2159], [8, 1189, 0.0382, 0.25420000000000004], [9, 1268, 0.0408, 0.2949], [10, 1086, 0.0349, 0.3299], [11, 920, 0.0296, 0.35950000000000004], [12, 931, 0.029900000000000003, 0.38939999999999997], [13, 819, 0.0263, 0.4157], [14, 1016, 0.0327, 0.4484], [15, 918, 0.029500000000000002, 0.4779], [16, 853, 0.0274, 0.5054], [17, 721, 0.0232, 0.5286], [18, 711, 0.0229, 0.5514], [19, 727, 0.023399999999999997, 0.5748], [20, 554, 0.0178, 0.5926]]

# %%
# write your code here
